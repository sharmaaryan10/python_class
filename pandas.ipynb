# %%
try:
    file = open('info.csv','x')
    file.close()
except:
    print("The file is already present. ")

# %%
import pandas as pd
df = pd.read_csv('info.csv')
df
# Out:
#    sn   name  age        add     phone
# 0   1    Ram   34  Kathmandu  98089996
# 1   2  Shyam   45  Bhaktapur    402938
# 2   3   Hari   56   Lalitpur    927858
# 3   4   Siva   18      Jhapa    279585
# 4   5  Nabin   45  Kathmandu   2548992
# 5   6   Sita   23    Chitwan   9813571

# %% [markdown]
# # reading rows

# %%
df = pd.read_csv('info.csv',nrows=4)
df
# Out:
#    sn   name  age        add     phone
# 0   1    Ram   34  Kathmandu  98089996
# 1   2  Shyam   45  Bhaktapur    402938
# 2   3   Hari   56   Lalitpur    927858
# 3   4   Siva   18      Jhapa    279585

# %%
df = pd.read_csv('info.csv',nrows=4,index_col = 'sn')
df
# Out:
#      name  age        add     phone
# sn
# 1     Ram   34  Kathmandu  98089996
# 2   Shyam   45  Bhaktapur    402938
# 3    Hari   56   Lalitpur    927858
# 4    Siva   18      Jhapa    279585

# %%
df = pd.read_csv('info.csv',index_col = 'sn')
df.head() 

# df.tail()
# Out:
#      name  age        add    phone
# sn
# 4    Siva   18      Jhapa   279585
# 5   Nabin   45  Kathmandu  2548992
# 6    Sita   23    Chitwan  9813571

# %%
df = pd.read_csv('info.csv',index_col = 'sn')
# df.head(4)

df.tail(3)
# Out:
#      name  age        add    phone
# sn
# 4    Siva   18      Jhapa   279585
# 5   Nabin   45  Kathmandu  2548992
# 6    Sita   23    Chitwan  9813571

# %% [markdown]
# # read different columns

# %%
df = pd.read_csv('info.csv',index_col = 'sn',usecols=['sn','name','phone'])
df

# can't remove sn column as it is used as index_col
# Out:
#      name     phone
# sn
# 1     Ram  98089996
# 2   Shyam    402938
# 3    Hari    927858
# 4    Siva    279585
# 5   Nabin   2548992
# 6    Sita   9813571

# %%
df = pd.read_csv('info.csv',index_col = 'sn')
df[['name','phone']]

# single bracket is used for single column, but here it gives error
# Out:
#      name     phone
# sn
# 1     Ram  98089996
# 2   Shyam    402938
# 3    Hari    927858
# 4    Siva    279585
# 5   Nabin   2548992
# 6    Sita   9813571

# %% [markdown]
# # index localizer

# %%
# iloc loc

df.iloc[1:4]
# Out:
#      name  age        add   phone
# sn
# 2   Shyam   45  Bhaktapur  402938
# 3    Hari   56   Lalitpur  927858
# 4    Siva   18      Jhapa  279585

# %%
df.loc[2:4]

# but must make sn no. as index_col
# Out:
#      name  age        add   phone
# sn
# 2   Shyam   45  Bhaktapur  402938
# 3    Hari   56   Lalitpur  927858
# 4    Siva   18      Jhapa  279585

# %%
df['name']

# it is called series 
# if used double bracket as above it is called data frame
# Out:
# sn
# 1      Ram
# 2    Shyam
# 3     Hari
# 4     Siva
# 5    Nabin
# 6     Sita
# Name: name, dtype: object

# %%
df['name'] == "Ram"
# Out:
# sn
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# Name: name, dtype: bool

# %%
df[df['name'] == "Ram"]
# Out:
#    name  age        add     phone
# sn
# 1   Ram   34  Kathmandu  98089996

# %%
df[df['age']> 35]
# Out:
#      name  age        add    phone
# sn
# 2   Shyam   45  Bhaktapur   402938
# 3    Hari   56   Lalitpur   927858
# 5   Nabin   45  Kathmandu  2548992

# %%
# AND case

df[(df['age']> 35) & (df['add']=='Kathmandu')]
# Out:
#      name  age        add    phone
# sn
# 5   Nabin   45  Kathmandu  2548992

# %%
# OR case

df[(df['age']> 35) | (df['add']=='Kathmandu')]
# Out:
#      name  age        add     phone
# sn
# 1     Ram   34  Kathmandu  98089996
# 2   Shyam   45  Bhaktapur    402938
# 3    Hari   56   Lalitpur    927858
# 5   Nabin   45  Kathmandu   2548992

# %% [markdown]
# #  creating dataframe from data inside variable

# %%
info = {'Name':["Ram","Shyam","Hari"],
       'Age':[24,25,26],
       'Address':["ktm",'bkt','Ltr']}

df = pd.DataFrame(info)
df
# Out:
#     Name  Age Address
# 0    Ram   24     ktm
# 1  Shyam   25     bkt
# 2   Hari   26     Ltr

# %% [markdown]
# # creating csv file from variable

# %%
info = {'Name':["Ram","Shyam","Hari"],
       'Age':[24,25,26],
       'Address':["ktm",'bkt','Ltr']}

df = pd.DataFrame(info)
df.to_csv('infox1.csv')

# %%
df = pd.read_csv('info.csv')

df1 = df[(df['age']> 35) | (df['add']=='Kathmandu')]
df1.to_csv('info1.csv')
